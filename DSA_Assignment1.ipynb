# %%
import pandas as pd

# %% [markdown]
# # Read the iris dataset to python environment.

# %%
data=pd.read_excel("D:\python\DSA-assignment1\iris.xls")
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # Display the columns in the iris dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
##for col in data.columns:
    print(col)
# Out:
# SL
# SW
# PL
# PW
# Classification

# %% [markdown]
# # Calculate the mean of each column of the iris dataset.

# %%
data.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Check for the null values present in the iris dataset

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Histogram representation of SL

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10, 7))
x = data["SL"]
  
plt.hist(x, bins = 20, color = "green", rwidth=0.9)
plt.title("SL in cm")
plt.xlabel("SL in cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Box Plot for Iris Data

# %%
new_data = data[["SL", "SW", "PL", "PW"]]
plt.figure(figsize = (10, 7))
new_data.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plotting using Seaborn on iris dataset

# %%
import seaborn as sns
iris=pd.read_excel("D:\python\DSA-assignment1\iris.xls")
iris = sns.load_dataset('iris')
sns.pairplot(iris)

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x="species", y="petal_length", data=iris, size=6)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(7,4))
sns.heatmap(iris.corr(),annot=True)
# Out:
# <AxesSubplot:>
